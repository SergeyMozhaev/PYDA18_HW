# %%
print("Введите день")
day = input()
day = int(day)

print("Введите месяц")
month = input()
month = month.lower()

err_day = False
err_month = False

if month == 'январь':
    if day < 1:
        err_day = True
    elif day <= 20:
        zodiak_sign = 'Козерог'
    elif day <= 31:
        zodiak_sign = 'Водолей'
    else:
        err_day = True
elif month == 'февраль':
    if day < 1:
        err_day = True
    elif day <= 19:
        zodiak_sign = 'Водолей'
    elif day <= 29:
        zodiak_sign = 'Рыбы'
    else:
        err_day = True
elif month == 'март':
    if day < 1:
        err_day = True
    elif day <= 20:
        zodiak_sign = 'Рыбы'
    elif day <= 31:
        zodiak_sign = 'Овен'
    else:
        err_day = True
elif month == 'апрель':
    if day < 1:
        err_day = True
    elif day <= 20:
        zodiak_sign = 'Овен'
    elif day <= 30:
        zodiak_sign = 'Телец'
    else:
        err_day = True
elif month == 'май':
    if day < 1:
        err_day = True
    elif day <= 21:
        zodiak_sign = 'Телец'
    elif day <= 31:
        zodiak_sign = 'Близнецы'
    else:
        err_day = True
elif month == 'июнь':
    if day < 1:
        err_day = True
    elif day <= 21:
        zodiak_sign = 'Близнецы'
    elif day <= 30:
        zodiak_sign = 'Рак'
    else:
        err_day = True
elif month == 'июль':
    if day < 1:
        err_day = True
    elif day <= 22:
        zodiak_sign = 'Рак'
    elif day <= 31:
        zodiak_sign = 'Лев'
    else:
        err_day = True
elif month == 'август':
    if day < 1:
        err_day = True
    elif day <= 21:
        zodiak_sign = 'Лев'
    elif day <= 31:
        zodiak_sign = 'Дева'
    else:
        err_day = True
elif month == 'сентябрь':
    if day < 1:
        err_day = True
    elif day <= 23:
        zodiak_sign = 'Дева'
    elif day <= 30:
        zodiak_sign = 'Весы'
    else:
        err_day = True
elif month == 'октябрь':
    if day < 1:
        err_day = True
    elif day <= 23:
        zodiak_sign = 'Весы'
    elif day <= 31:
        zodiak_sign = 'Скорпион'
    else:
        err_day = True
elif month == 'ноябрь':
    if day < 1:
        err_day = True
    elif day <= 22:
        zodiak_sign = 'Скорпион'
    elif day <= 30:
        zodiak_sign = 'Стрелец'
    else:
        err_day = True
elif month == 'декабрь':
    if day < 1:
        err_day = True
    elif day <= 22:
        zodiak_sign = 'Стрелец'
    elif day <= 31:
        zodiak_sign = 'Козерог'
    else:
        err_day = True
else:
    err_month = True

print()
if err_day:
    print("Неправильный день")
if err_month:
    print("Неправильный месяц")
if not err_day and not err_month:
    print("Ваш знак зодиака: " + zodiak_sign)
